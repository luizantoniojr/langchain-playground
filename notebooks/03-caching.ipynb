# %% [markdown]
# # Caching

# %% [markdown]
# ### Cache in-memory

# %%
from langchain_openai import ChatOpenAI

chat = ChatOpenAI()

# %% [markdown]
# #### Message setup

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Você é um assistente de IA que responde perguntas sobre a capital do Brasil."),
    HumanMessage(content="O que você pode me dizer sobre a capital do Brasil?"),
]

# %% [markdown]
# #### Cache configuration

# %%
from langchain_core.globals import set_llm_cache
from langchain_community.cache import InMemoryCache

set_llm_cache(InMemoryCache())

# %% [markdown]
# #### Invoke without cache

# %%
# %%time
chat.invoke(messages)
# Out:
# CPU times: total: 0 ns
# Wall time: 2.7 s
# AIMessage(content='A capital do Brasil é Brasília, localizada no Distrito Federal. Foi planejada e construída para ser a capital do país, e foi oficialmente inaugurada em 21 de abril de 1960. Brasília é conhecida por sua arquitetura modernista, projetada por Oscar Niemeyer, e por ser uma cidade onde estão localizadas diversas instituições do governo federal. Além disso, é uma cidade muito arborizada e com amplas áreas verdes, sendo considerada Patrimônio Mundial da UNESCO.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 119, 'prompt_tokens': 42, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D5JdIshJCPbjocPH3vAmTgjQvg0q3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c25ba-160a-7391-bda5-e6693093c3c2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 119, 'total_tokens': 161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# #### Invoke with cache

# %%
# %%time
chat.invoke(messages)
# Out:
# CPU times: total: 0 ns
# Wall time: 379 μs
# AIMessage(content='A capital do Brasil é Brasília, localizada no Distrito Federal. Foi planejada e construída para ser a capital do país, e foi oficialmente inaugurada em 21 de abril de 1960. Brasília é conhecida por sua arquitetura modernista, projetada por Oscar Niemeyer, e por ser uma cidade onde estão localizadas diversas instituições do governo federal. Além disso, é uma cidade muito arborizada e com amplas áreas verdes, sendo considerada Patrimônio Mundial da UNESCO.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 119, 'prompt_tokens': 42, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D5JdIshJCPbjocPH3vAmTgjQvg0q3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c25ba-160a-7391-bda5-e6693093c3c2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 119, 'total_tokens': 161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}, 'total_cost': 0})
